# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
from torchvision import transforms, datasets
import os
import matplotlib.pyplot as plt
import numpy as np
batch_size = 128
num_epochs = 20
learning_rate = 0.01
transformations = transforms.Compose([
    transforms.Resize((80, 80)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])
train_dataset = datasets.ImageFolder(root='./ProjectDatasetImages/Train', transform=transformations)
test_dataset = datasets.ImageFolder(root='./ProjectDatasetImages/Test', transform=transformations)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
#Plotting 25 images from the 1st batch
dataiter = iter(train_loader)
images, labels = next(dataiter)
plt.imshow(np.transpose(torchvision.utils.make_grid(
    images[:25], normalize=True, padding=1, nrow=5).numpy(), (1, 2, 0)))
plt.axis('off')
# Out:
# (-0.5, 405.5, 405.5, -0.5)

# %%
#Iterating over the training dataset and storing the target class for each sample
train_classes = []
for batch_idx, (data, target) in enumerate(train_loader):
    train_classes.extend(target.tolist())

#Calculating the unique classes and the respective counts and plotting them
unique, counts = np.unique(train_classes, return_counts=True)
names = list(train_dataset.class_to_idx.keys())
plt.bar(names, counts)
plt.xlabel("Target Classes")
plt.ylabel("Number of training instances")
# Out:
# Text(0, 0.5, 'Number of training instances')

# %%
import torch.nn as nn


# CNN architecture
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(128 * 10 * 10, 512)
        self.fc2 = nn.Linear(512, 5)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.conv3(x)
        x = self.relu(x)
        x = self.pool(x)
        x = x.view(-1, 128 * 10 * 10)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x
model = CNN()

# %%
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
#         print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch + 1, num_epochs, i + 1, len(train_loader), loss.item()))
        if (i + 1) % 10 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch + 1, num_epochs, i + 1, len(train_loader), loss.item()))
# Out:
# Epoch [1/20], Step [1/16], Loss: 0.1394
# Epoch [1/20], Step [2/16], Loss: 2.8970
# Epoch [1/20], Step [3/16], Loss: 0.5599
# Epoch [1/20], Step [4/16], Loss: 0.9086
# Epoch [1/20], Step [5/16], Loss: 0.6152
# Epoch [1/20], Step [6/16], Loss: 0.7085
# Epoch [1/20], Step [7/16], Loss: 0.5948
# Epoch [1/20], Step [8/16], Loss: 0.4661
# Epoch [1/20], Step [9/16], Loss: 0.5215
# Epoch [1/20], Step [10/16], Loss: 0.4622
# Epoch [1/20], Step [11/16], Loss: 0.5068
# Epoch [1/20], Step [12/16], Loss: 0.4350
# Epoch [1/20], Step [13/16], Loss: 0.4935
# Epoch [1/20], Step [14/16], Loss: 0.4055
# Epoch [1/20], Step [15/16], Loss: 0.4777
# Epoch [1/20], Step [16/16], Loss: 0.4278
# Epoch [2/20], Step [1/16], Loss: 0.5183
# Epoch [2/20], Step [2/16], Loss: 0.4008
# Epoch [2/20], Step [3/16], Loss: 0.4752
# Epoch [2/20], Step [4/16], Loss: 0.4877
# Epoch [2/20], Step [5/16], Loss: 0.3543
# Epoch [2/20], Step [6/16], Loss: 0.4408
# Epoch [2/20], Step [7/16], Loss: 0.4845
# Epoch [2/20], Step [8/16], Loss: 0.4418
# Epoch [2/20], Step [9/16], Loss: 0.3390
# Epoch [2/20], Step [10/16], Loss: 0.4055
# Epoch [2/20], Step [11/16], Loss: 0.3376
# Epoch [2/20], Step [12/16], Loss: 0.3348
# Epoch [2/20], Step [13/16], Loss: 0.2913
# Epoch [6/20], Step [5/16], Loss: 0.3566
# Epoch [6/20], Step [6/16], Loss: 0.1793
# Epoch [6/20], Step [7/16], Loss: 0.1719
# Epoch [6/20], Step [8/16], Loss: 0.2603
# Epoch [6/20], Step [9/16], Loss: 0.2884
# Epoch [6/20], Step [10/16], Loss: 0.2052
# Epoch [6/20], Step [11/16], Loss: 0.2049
# Epoch [6/20], Step [12/16], Loss: 0.2653
# Epoch [6/20], Step [13/16], Loss: 0.2409
# Epoch [6/20], Step [14/16], Loss: 0.2231
# Epoch [6/20], Step [15/16], Loss: 0.2027
# Epoch [6/20], Step [16/16], Loss: 0.0950
# Epoch [7/20], Step [1/16], Loss: 0.1592
# Epoch [7/20], Step [2/16], Loss: 0.3343
# Epoch [7/20], Step [3/16], Loss: 0.2895
# Epoch [7/20], Step [4/16], Loss: 0.2022
# Epoch [7/20], Step [5/16], Loss: 0.1476
# Epoch [7/20], Step [6/16], Loss: 0.1471
# Epoch [7/20], Step [7/16], Loss: 0.1452
# Epoch [7/20], Step [8/16], Loss: 0.1652
# Epoch [7/20], Step [9/16], Loss: 0.1297
# Epoch [7/20], Step [10/16], Loss: 0.1495
# Epoch [7/20], Step [11/16], Loss: 0.2849
# Epoch [7/20], Step [12/16], Loss: 0.1180
# Epoch [7/20], Step [13/16], Loss: 0.1444
# Epoch [7/20], Step [14/16], Loss: 0.1674
# Epoch [7/20], Step [15/16], Loss: 0.1967
# Epoch [7/20], Step [16/16], Loss: 0.1402
# Epoch [8/20], Step [1/16], Loss: 0.1650
# Epoch [8/20], Step [2/16], Loss: 0.0878
# Epoch [8/20], Step [3/16], Loss: 0.1037
# Epoch [8/20], Step [4/16], Loss: 0.1034
# Epoch [8/20], Step [5/16], Loss: 0.1468
# Epoch [8/20], Step [6/16], Loss: 0.1445
# Epoch [8/20], Step [7/16], Loss: 0.1412
# Epoch [8/20], Step [8/16], Loss: 0.1658
# Epoch [8/20], Step [9/16], Loss: 0.0840
# Epoch [8/20], Step [10/16], Loss: 0.1618
# Epoch [8/20], Step [11/16], Loss: 0.1147
# Epoch [8/20], Step [12/16], Loss: 0.1876
# Epoch [8/20], Step [13/16], Loss: 0.1711
# Epoch [8/20], Step [14/16], Loss: 0.0621
# Epoch [8/20], Step [15/16], Loss: 0.1228
# Epoch [8/20], Step [16/16], Loss: 0.1281
# Epoch [9/20], Step [1/16], Loss: 0.0928
# Epoch [9/20], Step [2/16], Loss: 0.0683
# Epoch [9/20], Step [3/16], Loss: 0.0933
# Epoch [9/20], Step [4/16], Loss: 0.1238
# Epoch [9/20], Step [5/16], Loss: 0.0871
# Epoch [9/20], Step [6/16], Loss: 0.1017
# Epoch [9/20], Step [7/16], Loss: 0.0855
# Epoch [9/20], Step [8/16], Loss: 0.0530
# Epoch [9/20], Step [9/16], Loss: 0.1433
# Epoch [9/20], Step [10/16], Loss: 0.0687

# %%
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print('Test Accuracy: {:.2f}%'.format(100 * correct / total))
# Out:
# Test Accuracy: 85.28%
